# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\sample\datafiles\dataset_1_202506210420.csv')

# %%
df
# Out:
#            destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny           55   2PM
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM
# 2      No Urgent Place  Friend(s)   Sunny           80  10AM
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12679             Home    Partner   Rainy           55   6PM
# 12680             Work      Alone   Rainy           55   7AM
# 12681             Work      Alone   Snowy           30   7AM
# 12682             Work      Alone   Snowy           30   7AM
# 12683             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1               Coffee House         2h  Female  21  Unmarried partner  ...
# ...

# %%
#get the weather, temperature
print(df[['weather', 'temperature']])
# Out:
#       weather  temperature
# 0       Sunny           55
# 1       Sunny           80
# 2       Sunny           80
# 3       Sunny           80
# 4       Sunny           80
# ...       ...          ...
# 12679   Rainy           55
# 12680   Rainy           55
# 12681   Snowy           30
# 12682   Snowy           30
# 12683   Sunny           80
#
# [12684 rows x 2 columns]

# %%
df[['weather', 'temperature']].head(10) # gets the top 10 weather, temperature
# Out:
#   weather  temperature
# 0   Sunny           55
# 1   Sunny           80
# 2   Sunny           80
# 3   Sunny           80
# 4   Sunny           80
# 5   Sunny           80
# 6   Sunny           55
# 7   Sunny           80
# 8   Sunny           80
# 9   Sunny           80

# %%
df
# Out:
#            destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny           55   2PM
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM
# 2      No Urgent Place  Friend(s)   Sunny           80  10AM
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12679             Home    Partner   Rainy           55   6PM
# 12680             Work      Alone   Rainy           55   7AM
# 12681             Work      Alone   Snowy           30   7AM
# 12682             Work      Alone   Snowy           30   7AM
# 12683             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1               Coffee House         2h  Female  21  Unmarried partner  ...
# ...

# %%
df['passanger'].unique()
# Out:
# array(['Alone', 'Friend(s)', 'Kid(s)', 'Partner'], dtype=object)

# %%
FilterHome = df['destination'] =='Home' # filter data as per Home.

# %%
df[FilterHome]
# Out:
#       destination passanger weather  temperature  time                 coupon  \
# 13           Home     Alone   Sunny           55   6PM                    Bar
# 14           Home     Alone   Sunny           55   6PM      Restaurant(20-50)
# 15           Home     Alone   Sunny           80   6PM           Coffee House
# 35           Home     Alone   Sunny           55   6PM                    Bar
# 36           Home     Alone   Sunny           55   6PM      Restaurant(20-50)
# ...           ...       ...     ...          ...   ...                    ...
# 12675        Home     Alone   Snowy           30  10PM           Coffee House
# 12676        Home     Alone   Sunny           80   6PM      Restaurant(20-50)
# 12677        Home   Partner   Sunny           30   6PM        Restaurant(<20)
# 12678        Home   Partner   Sunny           30  10PM        Restaurant(<20)
# 12679        Home   Partner   Rainy           55   6PM  Carry out & Take away
#
# ...

# %%
df.sort_values('coupon') # sort by coupon
# Out:
#            destination  passanger weather  temperature  time           coupon  \
# 11702             Home    Partner   Sunny           30  10PM              Bar
# 9930   No Urgent Place      Alone   Snowy           30   2PM              Bar
# 10632             Home      Alone   Rainy           55   6PM              Bar
# 7997   No Urgent Place  Friend(s)   Rainy           55  10PM              Bar
# 11166             Work      Alone   Snowy           30   7AM              Bar
# ...                ...        ...     ...          ...   ...              ...
# 10476             Home      Alone   Sunny           80   6PM  Restaurant(<20)
# 5447              Home      Alone   Sunny           80  10PM  Restaurant(<20)
# 10478             Home      Alone   Snowy           30  10PM  Restaurant(<20)
# 5440   No Urgent Place      Alone   Sunny           80   2PM  Restaurant(<20)
# 0      No Urgent Place      Alone   Sunny           55   2PM  Restaurant(<20)
#
# ...

# %%
df.columns
# Out:
# Index(['destination', 'passanger', 'weather', 'temperature', 'time', 'coupon',
#        'expiration', 'gender', 'age', 'maritalStatus', 'has_children',
#        'education', 'occupation', 'income', 'car', 'Bar', 'CoffeeHouse',
#        'CarryAway', 'RestaurantLessThan20', 'Restaurant20To50',
#        'toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min',
#        'direction_same', 'direction_opp', 'Y', 'row_count'],
#       dtype='object')

# %%
df.rename(columns ={'destination': 'Destination'}, inplace=True) # renaming the 'destination' to 'Destination'

# %%
df.columns[0]
# Out:
# 'Destination'

# %%
df[df.columns[0]]
# Out:
# 0        No Urgent Place
# 1        No Urgent Place
# 2        No Urgent Place
# 3        No Urgent Place
# 4        No Urgent Place
#               ...
# 12679               Home
# 12680               Work
# 12681               Work
# 12682               Work
# 12683               Work
# Name: Destination, Length: 12684, dtype: object

# %%
df.groupby('occupation')['occupation'].count() # occupation data as per group by occupation
# Out:
# occupation
# Architecture & Engineering                    175
# Arts Design Entertainment Sports & Media      629
# Building & Grounds Cleaning & Maintenance      44
# Business & Financial                          544
# Community & Social Services                   241
# Computer & Mathematical                      1408
# Construction & Extraction                     154
# Education&Training&Library                    943
# Farming Fishing & Forestry                     43
# Food Preparation & Serving Related            298
# Healthcare Practitioners & Technical          244
# Healthcare Support                            242
# Installation Maintenance & Repair             133
# Legal                                         219
# Life Physical Social Science                  170
# Management                                    838
# Office & Administrative Support               639
# Personal Care & Service                       175
# ...

# %%
for occupation,groupby in df.groupby('occupation'):
    print(f'{occupation}')
# Out:
# Architecture & Engineering
# Arts Design Entertainment Sports & Media
# Building & Grounds Cleaning & Maintenance
# Business & Financial
# Community & Social Services
# Computer & Mathematical
# Construction & Extraction
# Education&Training&Library
# Farming Fishing & Forestry
# Food Preparation & Serving Related
# Healthcare Practitioners & Technical
# Healthcare Support
# Installation Maintenance & Repair
# Legal
# Life Physical Social Science
# Management
# Office & Administrative Support
# Personal Care & Service
# Production Occupations
# Protective Service
# Retired
# Sales & Related
# Student
# Transportation & Material Moving
# Unemployed

# %%
df.groupby('weather')['temperature'].mean().astype(int) # average temperature and group by weather
# Out:
# weather
# Rainy    55
# Snowy    30
# Sunny    68
# Name: temperature, dtype: int32

# %%
df.groupby('weather')['temperature'].nunique().to_frame('count_of_temperature').reset_index() # group by weather and showing count of temperature
# Out:
#   weather  count_of_temperature
# 0   Rainy                     1
# 1   Snowy                     1
# 2   Sunny                     3

# %%
df.groupby('weather')['temperature'].sum().to_frame('sum_of_temperature').reset_index() # group by weather and sum of temperature
# Out:
#   weather  sum_of_temperature
# 0   Rainy               66550
# 1   Snowy               42150
# 2   Sunny              694220

# %%
df.groupby('weather')['temperature'].min().to_frame('min_temperature').reset_index() # group by weather and minimum temperature
# Out:
#   weather  min_temperature
# 0   Rainy               55
# 1   Snowy               30
# 2   Sunny               30

# %%
df.groupby('weather')['temperature'].max().to_frame('max_temperature').reset_index() # group by weather and maximum temperature
# Out:
#   weather  max_temperature
# 0   Rainy               55
# 1   Snowy               30
# 2   Sunny               80

# %%
df.groupby('occupation').filter(lambda x: x ['occupation'].iloc[0] == 'Student') #filter by occupation ='Student'
# Out:
#            Destination  passanger weather  temperature  time  \
# 44     No Urgent Place      Alone   Sunny           55   2PM
# 45     No Urgent Place  Friend(s)   Sunny           80  10AM
# 46     No Urgent Place  Friend(s)   Sunny           80  10AM
# 47     No Urgent Place  Friend(s)   Sunny           80  10AM
# 48     No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12585             Work      Alone   Rainy           55   7AM
# 12586             Work      Alone   Snowy           30   7AM
# 12587             Work      Alone   Snowy           30   7AM
# 12588             Work      Alone   Snowy           30   7AM
# 12589             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration gender age maritalStatus  ...  \
# 44           Restaurant(<20)         1d   Male  46        Single  ...
# 45              Coffee House         2h   Male  46        Single  ...
# ...

# %%
df
# Out:
#            Destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny           55   2PM
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM
# 2      No Urgent Place  Friend(s)   Sunny           80  10AM
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12679             Home    Partner   Rainy           55   6PM
# 12680             Work      Alone   Rainy           55   7AM
# 12681             Work      Alone   Snowy           30   7AM
# 12682             Work      Alone   Snowy           30   7AM
# 12683             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1               Coffee House         2h  Female  21  Unmarried partner  ...
# ...

# %%
df[df['occupation'] == 'Student']
# Out:
#            Destination  passanger weather  temperature  time  \
# 44     No Urgent Place      Alone   Sunny           55   2PM
# 45     No Urgent Place  Friend(s)   Sunny           80  10AM
# 46     No Urgent Place  Friend(s)   Sunny           80  10AM
# 47     No Urgent Place  Friend(s)   Sunny           80  10AM
# 48     No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12585             Work      Alone   Rainy           55   7AM
# 12586             Work      Alone   Snowy           30   7AM
# 12587             Work      Alone   Snowy           30   7AM
# 12588             Work      Alone   Snowy           30   7AM
# 12589             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration gender age maritalStatus  ...  \
# 44           Restaurant(<20)         1d   Male  46        Single  ...
# 45              Coffee House         2h   Male  46        Single  ...
# ...

# %%
df1 = df

# %%
pd.concat([df,df1])['Destination'].drop_duplicates() #drop duplicates and show unique
# Out:
# 0     No Urgent Place
# 13               Home
# 16               Work
# Name: Destination, dtype: object

# %%
pd.merge(df,df1[['Destination','time']],on='time',how='inner')[['destination']]
